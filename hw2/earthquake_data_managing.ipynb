# %% [markdown]
# <a href="https://colab.research.google.com/github/zberis/DSPS_ZBeris/blob/main/hw2/earthquake_data_managing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#these are all the imports you need
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
plt.rcParams.update({
    "font.family": "DejaVu Sans",  # Other options: "Arial", "sans-serif"
    "font.size": 12,
    "axes.labelsize": 14,
    "axes.titlesize": 16,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
})
...
# Out:
# Ellipsis

# %%
earthquakes = pd.read_csv('https://raw.githubusercontent.com/fedhere/DSPS_FBianco/refs/heads/main/data/earthquakes.csv', sep = r"\s+")

# %%
earthquakes.shape
# Out:
# (70798, 13)

# %%
earthquakes.head(10)
# Out:
#    #YYY/MM/DD  HH:mm:SS.ss  ET GT   MAG  M     LAT      LON  DEPTH  Q   EVID  \
# 0  1984/01/01  01:30:57.52  eq  l  2.02  c  33.246 -116.433    1.6  C  28255
# 1  1984/01/01  05:31:34.16  eq  l  2.12  c  32.945 -116.295    5.4  C  28259
# 2  1984/01/01  06:59:05.14  eq  l  2.43  c  33.343 -117.628    5.6  C  28260
# 3  1984/01/01  11:10:25.29  eq  l  2.07  c  33.668 -116.780   13.8  C  28270
# 4  1984/01/01  19:38:19.79  eq  l  2.13  c  33.963 -116.290    2.7  C  28553
# 5  1984/01/01  19:39:19.67  eq  l  2.13  c  34.062 -117.325   18.5  C  28282
# 6  1984/01/01  20:19:47.21  eq  l  2.02  c  35.180 -119.016   13.8  C  28284
# 7  1984/01/02  03:51:52.76  eq  l  2.97  c  31.785 -115.988    5.6  C  28297
# 8  1984/01/02  05:00:12.44  eq  l  3.24  l  35.958 -118.332    4.5  C  28575
# 9  1984/01/02  05:02:17.29  eq  l  2.17  c  35.936 -118.312    0.8  C  28299
#
#    NPH  NGRM
# 0   13    17
# 1   18    42
# 2   13    30
# 3   19    40
# 4   40    49
# 5   32    41
# 6   31    59
# ...

# %%
earthquakes.tail(10)
# Out:
#        #YYY/MM/DD  HH:mm:SS.ss  ET GT   MAG  M       LAT        LON  DEPTH  Q  \
# 70788  2002/12/28  22:07:52.17  eq  l  2.13  l  33.18383 -115.56567    2.9  A
# 70789  2002/12/29  01:55:15.53  eq  l  2.22  l  35.31600 -118.66217    2.1  A
# 70790  2002/12/29  02:36:07.36  eq  l  2.07  l  35.31817 -118.66883    2.1  A
# 70791  2002/12/29  19:36:07.23  eq  l  3.15  l  35.31500 -118.65583    1.7  A
# 70792  2002/12/29  19:36:54.42  eq  l  2.50  h  35.31333 -118.68000    4.8  A
# 70793  2002/12/29  19:37:24.56  eq  l  2.21  l  35.31400 -118.66767    3.7  A
# 70794  2002/12/29  20:17:33.40  eq  l  2.02  l  35.32133 -118.66000    1.8  A
# 70795  2002/12/29  20:21:28.73  eq  l  2.07  l  35.32150 -118.66617    1.9  A
# 70796  2002/12/30  21:51:52.55  eq  l  2.31  l  35.31867 -118.66250    1.5  A
# 70797  2002/12/30  23:38:49.79  eq  l  2.05  l  35.31450 -118.66333    1.9  A
#
#           EVID  NPH  NGRM
# 70788  9874533   19   261
# 70789  9874565   56   365
# 70790  9874577   50   198
# ...

# %%
earthquakes.columns
# Out:
# Index(['#YYY/MM/DD', 'HH:mm:SS.ss', 'ET', 'GT', 'MAG', 'M', 'LAT', 'LON',
#        'DEPTH', 'Q', 'EVID', 'NPH', 'NGRM'],
#       dtype='object')

# %%
earthquakes = earthquakes[['#YYY/MM/DD', 'HH:mm:SS.ss', 'MAG']]

# %%
earthquakes.head()
# Out:
#    #YYY/MM/DD  HH:mm:SS.ss   MAG
# 0  1984/01/01  01:30:57.52  2.02
# 1  1984/01/01  05:31:34.16  2.12
# 2  1984/01/01  06:59:05.14  2.43
# 3  1984/01/01  11:10:25.29  2.07
# 4  1984/01/01  19:38:19.79  2.13

# %%
earthquakes.dtypes
# Out:
# #YYY/MM/DD      object
# HH:mm:SS.ss     object
# MAG            float64
# dtype: object

# %%
earthquakes = earthquakes.rename({"#YYY/MM/DD": "Date", "HH:mm:SS.ss":"Time", "MAG": "Magnitude"}, axis = 1)

# %%
earthquakes
# Out:
#              Date         Time  Magnitude
# 0      1984/01/01  01:30:57.52       2.02
# 1      1984/01/01  05:31:34.16       2.12
# 2      1984/01/01  06:59:05.14       2.43
# 3      1984/01/01  11:10:25.29       2.07
# 4      1984/01/01  19:38:19.79       2.13
# ...           ...          ...        ...
# 70793  2002/12/29  19:37:24.56       2.21
# 70794  2002/12/29  20:17:33.40       2.02
# 70795  2002/12/29  20:21:28.73       2.07
# 70796  2002/12/30  21:51:52.55       2.31
# 70797  2002/12/30  23:38:49.79       2.05
#
# [70798 rows x 3 columns]

# %%
earthquakes.describe()
# Out:
#           Magnitude
# count  70798.000000
# mean       2.417826
# std        0.407683
# min        2.000000
# 25%        2.120000
# 50%        2.300000
# 75%        2.590000
# max        7.100000

# %%
earthquakes["Date"].map(pd.to_datetime)
# Out:
# 0       1984-01-01
# 1       1984-01-01
# 2       1984-01-01
# 3       1984-01-01
# 4       1984-01-01
#            ...
# 70793   2002-12-29
# 70794   2002-12-29
# 70795   2002-12-29
# 70796   2002-12-30
# 70797   2002-12-30
# Name: Date, Length: 70798, dtype: datetime64[ns]

# %%
earthquakes["New Date"] = earthquakes["Date"].map(pd.to_datetime)

# %%
for i in earthquakes.index:
  if earthquakes.loc[i,"Time"].endswith('60.00'):
    print(earthquakes.loc[i, "Time"])
    earthquakes.loc[i, "Time"] = earthquakes.loc[i, "Time"][:6] + '59.99'
# Out:
# 04:48:60.00
# 14:19:60.00
# 21:48:60.00
# 15:34:60.00
# 06:41:60.00

# %%
earthquakes["DateTime"] = earthquakes["Date"] + " " + earthquakes["Time"];

# %%
earthquakes["DateTime"] = earthquakes["DateTime"].map(pd.to_datetime)

# %%
earthquakes
# Out:
#              Date         Time  Magnitude                DateTime
# 0      1984/01/01  01:30:57.52       2.02 1984-01-01 01:30:57.520
# 1      1984/01/01  05:31:34.16       2.12 1984-01-01 05:31:34.160
# 2      1984/01/01  06:59:05.14       2.43 1984-01-01 06:59:05.140
# 3      1984/01/01  11:10:25.29       2.07 1984-01-01 11:10:25.290
# 4      1984/01/01  19:38:19.79       2.13 1984-01-01 19:38:19.790
# ...           ...          ...        ...                     ...
# 70793  2002/12/29  19:37:24.56       2.21 2002-12-29 19:37:24.560
# 70794  2002/12/29  20:17:33.40       2.02 2002-12-29 20:17:33.400
# 70795  2002/12/29  20:21:28.73       2.07 2002-12-29 20:21:28.730
# 70796  2002/12/30  21:51:52.55       2.31 2002-12-30 21:51:52.550
# 70797  2002/12/30  23:38:49.79       2.05 2002-12-30 23:38:49.790
#
# [70798 rows x 4 columns]

# %%
earthquakes = earthquakes.drop(["Date", "Time"], axis = 1)

# %%
earthquakes
# Out:
#        Magnitude                DateTime
# 0           2.02 1984-01-01 01:30:57.520
# 1           2.12 1984-01-01 05:31:34.160
# 2           2.43 1984-01-01 06:59:05.140
# 3           2.07 1984-01-01 11:10:25.290
# 4           2.13 1984-01-01 19:38:19.790
# ...          ...                     ...
# 70793       2.21 2002-12-29 19:37:24.560
# 70794       2.02 2002-12-29 20:17:33.400
# 70795       2.07 2002-12-29 20:21:28.730
# 70796       2.31 2002-12-30 21:51:52.550
# 70797       2.05 2002-12-30 23:38:49.790
#
# [70798 rows x 2 columns]

# %%
earthquakes["DateTime"].diff()
# Out:
# 0                          NaT
# 1       0 days 04:00:36.640000
# 2       0 days 01:27:30.980000
# 3       0 days 04:11:20.150000
# 4       0 days 08:27:54.500000
#                  ...
# 70793   0 days 00:00:30.140000
# 70794   0 days 00:40:08.840000
# 70795   0 days 00:03:55.330000
# 70796   1 days 01:30:23.820000
# 70797   0 days 01:46:57.240000
# Name: DateTime, Length: 70798, dtype: timedelta64[ns]

# %%
earthquakes["DateTime"].mean()
# Out:
# Timestamp('1992-11-08 04:14:59.083973376')

# %%
earthquakes.shape
# Out:
# (70798, 2)

# %%
earthquakes.describe()
# Out:
#           Magnitude                       DateTime
# count  70798.000000                          70798
# mean       2.417826  1992-11-08 04:14:59.083973376
# min        2.000000     1984-01-01 01:30:57.520000
# 25%        2.120000  1988-05-05 20:49:20.964999936
# 50%        2.300000     1992-07-18 06:27:56.530000
# 75%        2.590000  1996-10-29 15:31:47.564999936
# max        7.100000     2002-12-30 23:38:49.790000
# std        0.407683                            NaN
